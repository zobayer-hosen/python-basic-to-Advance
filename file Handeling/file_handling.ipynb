# %%
f =open('files/sample.txt','w')
f.write("my name is zobayer")
f.write('\n how are you')
f.close()

# %%
f = open("files/sample.txt",'w')
f.write("zobayer hosen")
f.close()

# %%
f = open("files/sample.txt",'a') # this "a" use for adding content newly in the old file
f.write("\nsomething else")
f.close()

# %%
#write Line
L= ["my name is"," zobayer","\ni am 23 year old","\n and i am happy and i am struggling"]

f = open('files/sample.txt','w')
f.writelines(L)
f.close()

# %%
L= ["my name is"," zobayer","\ni am 23 year old","\n and i am happy and i am struggling"]

f = open('files/sample.txt','a') # do the append command
f.writelines(L)
f.close()

# %%
f = open("files/sample.txt",'r')
a=f.read()
print(a)
f.close(
)
# Out:
# my name is zobayer
# i am 23 year old
#  and i am happy and i am strugglingmy name is zobayer
# i am 23 year old
#  and i am happy and i am struggling

# %%
f = open("files/sample.txt",'r')
s = f.read(15)
print(s)
f.close()
# Out:
# my name is zoba

# %%
#readline read one single line innner the file
f = open("files/sample.txt",'r')
while True:
    data = f.readline()
    if data == "":
        break
    else:
        print(data,end="")



f.close()
# Out:
# my name is zobayer
# i am 23 year old
#  and i am happy and i am strugglingmy name is zobayer
# i am 23 year old
#  and i am happy and i am struggling
