# %%
print("my name is zobayer")
# Out:
# my name is zobayer

# %%
a=10
b=20
a+b
# Out:
# 30

# %% [markdown]
# MY FIRST PYTHON PROGRAM

# %%
print("hello world")
# Out:
# hello world

# %%
print("9")
print(type("9")) # showing the actual printed value
type("9")# showing the return value
# Out:
# 9
# <class 'str'>
# str

# %%
print("hello",12,4,5,7,4,4,True)
# Out:
# hello 12 4 5 7 4 4 True

# %% [markdown]
# ## Data type in python and Comment

# %%
print('my name zobayer hosen')
# Out:
# my name zobayer hosen

# %%
"""this is multiline commnet this print function prints a sentence like this"""
# Out:
# 'this is multiline commnet this print function prints a sentence like this'

# %%
a = 2000000000000000000000000000000000000000000000000000
type(a)
# Out:
# int

# %%
print(5+3j)
type(5+3j)
# Out:
# (5+3j)
# complex

# %%
a = {"name":"zobayer","age":20}
print(a)
type(a)
# Out:
# {'name': 'zobayer', 'age': 20}
# dict

# %%
#Dynamic typing means which was identy the type program itself ,it's a bultin
#static typing:give the the actual datatype and then program identify the which data type is

# %%
# valiable naming convention
#can't start with number
#can't use any spacial chars excepts _

name$ = "zobauer"
print(name$)
# Out:
#   File "/tmp/ipython-input-1448408818.py", line 5
#     name$ = "zobauer"
#         ^
# SyntaxError: invalid syntax

# %%
nam$e = "zobayer"
print(nam$e)
# Out:
#   File "/tmp/ipython-input-786091400.py", line 1
#     nam$e = "zobayer"
#        ^
# SyntaxError: invalid syntax

# %%
 a = int(input("my age is  "))
# Out:
# my age is  23

# %%
a = int(input("Enter your first number"))
b=int(input("Enter your second number"))

d = a+b
print(d)
# Out:
# Enter your first number2
# Enter your second number4
# 6

# %% [markdown]
# Type Conversion in python :

# %%
#implicit := internal by python
#Explicit - By the programmer

# %%
a = "zoabyer"
print(a)
type(a)
#b = int(a)
# Out:
# zoabyer
# str

# %%
a = 0b1010 #Binary Literals
b  = 100 #Decimal literal
c = 0o310 #Octal Literal
c=0x12c

# %%
unicode = u"\U0001f600\U0001F606\U0001F923"
print(unicode)
# Out:
# 😀😆🤣

# %%
# always in python true gives 1 and false gives 0

# %%
a = True + 10
print(a)
# Out:
# 11

# %% [markdown]
# ## logical opertion

# %%
print(0 and 1)
# Out:
# 0

# %%
print(0 or 1)
# Out:
# 1

# %%
print(not 1)
# Out:
# False

# %%
print(not 0)
# Out:
# True

# %%
print(not True)
# Out:
# False
