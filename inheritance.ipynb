# %% [markdown]
# ## interitance in oop
# Inheritance allows us to define a class that inherits all the methods and properties from another class .Parent class is the class being inherited form,also called base class.Child class is the class that inherits from another class ,also called derived class
# . non pritvate attribute
# .non private methods

# %%
class User:
    def __int__(self):
        self.name = "zobayer"
        self.gender = "Male"
    def login(self):
        print("Login Done")
    def register(self):
        print("Register Done!")
class Student(User):
    def __int__(self):
        self.rollno = 12
    def enroll(self):
        print("Enroll the Course")

class Instructor(User):
    def __init__(self):
        self.idno = 120
    def create(self):
        print("Created the course !")

# %%
s = Student()

# %%
s.enroll()
# Out:
# Enroll the Course

# %%
s.login()
# Out:
# Login Done

# %%
s.register()
# Out:
# Register Done!

# %%
class User:
    def __init__(self):
        self.name = "zobayer"
        self.gender = "male"
    def login(self):
        print("Login Done!")
    def register(self):
        print("register Done!")

class Student(User):
    def __init__(self):
        self.rollno = 12
    def enroll(self):
        print("Enrolled the course")

# %%
s = Student()

# %%
s.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
class Phone:
    def __init__(self,price,brand, camera):
        print("Inside Phone constructor")
        self.price = price
        self.brand = brand
        self.camera = camera


class SmartPhone(Phone):
    def __init__(self,price,brand,camera,os,ram):
        print("Inside SmartPhone consturctor")
        super().__init__(price,brand, camera)
        self.os = os
        self.ram = ram

# %%
S = SmartPhone(34567890,"phone",3,"anroid",16)
# Out:
# Inside SmartPhone consturctor
# Inside Phone constructor
